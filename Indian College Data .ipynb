# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
College=pd.read_csv('College_data.csv')
College
# Out:
#                                            College_Name       State  \
# 0                Indian Institute of Technology Madras   Tamil nadu
# 1              College of Engineering, Anna University   Tamil nadu
# 2                          NIT Trichy, Tiruchirappalli   Tamil nadu
# 3                      Vellore Institute of Technology   Tamil nadu
# 4                 SRM Engineering College, Kanchipuram   Tamil nadu
# ...                                                 ...         ...
# 6783  Andaman & Nicobar Islands Institute of Medical...     Andaman
# 6784  Plastindia International University, Dadra & N...       Dadra
# 6785          SSR Institute of Management and Research        Dadra
# 6786  Institute of Hotel Management and Catering Tec...       Dadra
# 6787                     Government Polytechnic, Daman        Daman
#
#                 Stream    UG_fee    PG_fee Rating Academic Accommodation  \
# 0          Engineering    75,116    23,070    8.7        9           7.9
# ...

# %% [markdown]
# # Data Cleaning

# %%
College.isnull().sum()
# Out:
# College_Name      0
# State             0
# Stream            0
# UG_fee            0
# PG_fee            0
# Rating            0
# Academic          0
# Accommodation     0
# Faculty           0
# Infrastructure    0
# Placement         0
# Social_Life       0
# dtype: int64

# %%
College.dtypes
# Out:
# College_Name      object
# State             object
# Stream            object
# UG_fee            object
# PG_fee            object
# Rating            object
# Academic          object
# Accommodation     object
# Faculty           object
# Infrastructure    object
# Placement         object
# Social_Life       object
# dtype: object

# %%
College.drop(College[College.Rating == '--'].index,inplace=True)
College.drop(College[College.Academic == '--'].index,inplace=True)
College.drop(College[College.Accommodation == '--'].index,inplace=True)
College.drop(College[College.Faculty == '--'].index,inplace=True)
College.drop(College[College.Infrastructure == '--'].index,inplace=True)
College.drop(College[College.Placement == '--'].index,inplace=True)
College.drop(College[College.Social_Life == '--'].index,inplace=True)
College.drop(College[College.College_Name == '--'].index,inplace=True)
College.drop(College[College.State == '--'].index,inplace=True)
College.drop(College[College.Stream == '--'].index,inplace=True)
College.drop(College[College.UG_fee == '--'].index,inplace=True)
College.drop(College[College.PG_fee == '--'].index,inplace=True)
College
# Out:
#                                   College_Name       State       Stream  \
# 0       Indian Institute of Technology Madras   Tamil nadu  Engineering
# 1     College of Engineering, Anna University   Tamil nadu  Engineering
# 2                 NIT Trichy, Tiruchirappalli   Tamil nadu  Engineering
# 3             Vellore Institute of Technology   Tamil nadu  Engineering
# 4        SRM Engineering College, Kanchipuram   Tamil nadu  Engineering
# ...                                        ...         ...          ...
# 6760                       Mizoram University      Mizoram         Arts
# 6764                       Mizoram University      Mizoram  Agriculture
# 6773  Jawaharlal Nehru Rajkeeya Mahavidyalaya      Andaman      Science
# 6776  Jawaharlal Nehru Rajkeeya Mahavidyalaya      Andaman     Commerce
# 6778  Jawaharlal Nehru Rajkeeya Mahavidyalaya      Andaman         Arts
#
#         UG_fee    PG_fee Rating Academic Accommodation Faculty Infrastructure  \
# ...

# %%
# Reset Index
College.reset_index(drop=True,inplace=True)
College
# Out:
#                                   College_Name       State       Stream  \
# 0       Indian Institute of Technology Madras   Tamil nadu  Engineering
# 1     College of Engineering, Anna University   Tamil nadu  Engineering
# 2                 NIT Trichy, Tiruchirappalli   Tamil nadu  Engineering
# 3             Vellore Institute of Technology   Tamil nadu  Engineering
# 4        SRM Engineering College, Kanchipuram   Tamil nadu  Engineering
# ...                                        ...         ...          ...
# 3190                       Mizoram University      Mizoram         Arts
# 3191                       Mizoram University      Mizoram  Agriculture
# 3192  Jawaharlal Nehru Rajkeeya Mahavidyalaya      Andaman      Science
# 3193  Jawaharlal Nehru Rajkeeya Mahavidyalaya      Andaman     Commerce
# 3194  Jawaharlal Nehru Rajkeeya Mahavidyalaya      Andaman         Arts
#
#         UG_fee    PG_fee Rating Academic Accommodation Faculty Infrastructure  \
# ...

# %%
College.dtypes
# Out:
# College_Name      object
# State             object
# Stream            object
# UG_fee            object
# PG_fee            object
# Rating            object
# Academic          object
# Accommodation     object
# Faculty           object
# Infrastructure    object
# Placement         object
# Social_Life       object
# dtype: object

# %%
# Converting the object datatype into float for numerical vaues
College["UG_fee"]=College["UG_fee"].str.replace(',','').astype('float64')
College["PG_fee"]=College["PG_fee"].str.replace(',','').astype('float64')
College["Placement"]=College["Placement"].astype("float64")
College["Rating"]=College["Rating"].astype("float64")
College["Accommodation"]=College["Accommodation"].astype("float64")
College["Academic"]=College["Academic"].astype("float64")
College["Faculty"]=College["Faculty"].astype("float64")
College["Social_Life"]=College["Social_Life"].astype("float64")
College["Infrastructure"]=College["Infrastructure"].astype("float64")

# %%
College.dtypes
# Out:
# College_Name       object
# State              object
# Stream             object
# UG_fee            float64
# PG_fee            float64
# Rating            float64
# Academic          float64
# Accommodation     float64
# Faculty           float64
# Infrastructure    float64
# Placement         float64
# Social_Life       float64
# dtype: object

# %%
College
# Out:
#                                   College_Name       State       Stream  \
# 0       Indian Institute of Technology Madras   Tamil nadu  Engineering
# 1     College of Engineering, Anna University   Tamil nadu  Engineering
# 2                 NIT Trichy, Tiruchirappalli   Tamil nadu  Engineering
# 3             Vellore Institute of Technology   Tamil nadu  Engineering
# 4        SRM Engineering College, Kanchipuram   Tamil nadu  Engineering
# ...                                        ...         ...          ...
# 3190                       Mizoram University      Mizoram         Arts
# 3191                       Mizoram University      Mizoram  Agriculture
# 3192  Jawaharlal Nehru Rajkeeya Mahavidyalaya      Andaman      Science
# 3193  Jawaharlal Nehru Rajkeeya Mahavidyalaya      Andaman     Commerce
# 3194  Jawaharlal Nehru Rajkeeya Mahavidyalaya      Andaman         Arts
#
#         UG_fee    PG_fee  Rating  Academic  Accommodation  Faculty  \
# ...

# %% [markdown]
# # Visualisation

# %%
College.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3195 entries, 0 to 3194
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   College_Name    3195 non-null   object
#  1   State           3195 non-null   object
#  2   Stream          3195 non-null   object
#  3   UG_fee          3195 non-null   float64
#  4   PG_fee          3195 non-null   float64
#  5   Rating          3195 non-null   float64
#  6   Academic        3195 non-null   float64
#  7   Accommodation   3195 non-null   float64
#  8   Faculty         3195 non-null   float64
#  9   Infrastructure  3195 non-null   float64
#  10  Placement       3195 non-null   float64
#  11  Social_Life     3195 non-null   float64
# dtypes: float64(9), object(3)
# memory usage: 299.7+ KB

# %%
College.describe()
# Out:
#              UG_fee        PG_fee       Rating     Academic  Accommodation  \
# count  3.195000e+03  3.195000e+03  3195.000000  3195.000000    3195.000000
# mean   1.298486e+05  1.247122e+05     7.873239     8.175524       7.381189
# std    2.623158e+05  3.340275e+05     0.649325     0.645248       0.897279
# min    2.650000e+02  2.790000e+02     3.800000     4.000000       1.000000
# 25%    2.500000e+04  2.600000e+04     7.500000     7.800000       7.000000
# 50%    6.820000e+04  6.500000e+04     7.900000     8.200000       7.500000
# 75%    1.250000e+05  1.164600e+05     8.300000     8.600000       7.900000
# max    5.000000e+06  8.230000e+06     9.700000     9.800000       9.800000
#
#            Faculty  Infrastructure    Placement  Social_Life
# count  3195.000000     3195.000000  3195.000000  3195.000000
# mean      8.142754        8.066917     7.391956     8.017872
# std       0.641368        0.769547     1.053153     0.770164
# ...

# %% [markdown]
# # All Data Of Engineering Colleges

# %%
Engineering_Colleges=College[College["Stream"]=="Engineering"]
Engineering_Colleges
# Out:
#                                   College_Name       State       Stream  \
# 0       Indian Institute of Technology Madras   Tamil nadu  Engineering
# 1     College of Engineering, Anna University   Tamil nadu  Engineering
# 2                 NIT Trichy, Tiruchirappalli   Tamil nadu  Engineering
# 3             Vellore Institute of Technology   Tamil nadu  Engineering
# 4        SRM Engineering College, Kanchipuram   Tamil nadu  Engineering
# ...                                        ...         ...          ...
# 3170          Manipur Institute of Technology      Manipur  Engineering
# 3171          Central Agricultural University      Manipur  Engineering
# 3172                       Manipur University      Manipur  Engineering
# 3179         National Institute of Technology      Mizoram  Engineering
# 3180                       Mizoram University      Mizoram  Engineering
#
#         UG_fee    PG_fee  Rating  Academic  Accommodation  Faculty  \
# ...

# %% [markdown]
# # All Data Of Science Colleges

# %%
Science_Colleges=College[College["Stream"]=="Science"]
Science_Colleges
# Out:
#                                          College_Name       State   Stream  \
# 653                          Loyola College, Chennai   Tamil nadu  Science
# 654                      Presidency College, Chennai   Tamil nadu  Science
# 655                    Stella Maris College, Chennai   Tamil nadu  Science
# 656      PSG College of Arts and Science, Coimbatore   Tamil nadu  Science
# 657   PSGR Krishnammal College for Women, Coimbatore   Tamil nadu  Science
# ...                                               ...         ...      ...
# 3174                 Central Agricultural University      Manipur  Science
# 3175                      National Sports University      Manipur  Science
# 3183            Pachhunga University College, Aizawl      Mizoram  Science
# 3184                              Mizoram University      Mizoram  Science
# 3192         Jawaharlal Nehru Rajkeeya Mahavidyalaya      Andaman  Science
#
#        UG_fee   PG_fee  Rating  Academic  Accommodation  Faculty  \
# ...

# %%
College.groupby("State")["Stream"].value_counts()
# Out:
# State           Stream
# Andaman         Science              1
#                 Commerce             1
#                 Arts                 1
# Andhra pradesh  Engineering         28
#                 Pharmacy            16
#                                     ..
# West bengal     Arts                11
#                 Law                 10
#                 Hotel-management     8
#                 Agriculture          7
#                 Medical              4
# Name: count, Length: 299, dtype: int64

# %% [markdown]
# # States with minimum no. of stream

# %%
College.groupby("State")["Stream"].min()
# Out:
# State
# Andaman                     Arts
# Andhra pradesh       Agriculture
# Arunachal pradesh    Agriculture
# Assam                Agriculture
# Bihar                Agriculture
# Chandigarh                  Arts
# Chhattisgarh         Agriculture
# Delhi ncr            Agriculture
# Goa                         Arts
# Gujarat              Agriculture
# Haryana              Agriculture
# Himachal pradesh     Agriculture
# Jammu                Agriculture
# Jharkhand            Agriculture
# Karnataka            Agriculture
# Kerala               Agriculture
# Madhya pradesh       Agriculture
# Maharashtra          Agriculture
# Manipur              Agriculture
# Meghalaya            Agriculture
# Mizoram              Agriculture
# Nagaland                    Arts
# Orissa               Agriculture
# Puducherry           Agriculture
# Punjab               Agriculture
# Rajasthan            Agriculture
# Sikkim               Agriculture
# Tamil nadu           Agriculture
# ...

# %% [markdown]
# # Sum Of PG_Fees State wise

# %%
College.groupby(["State"])["PG_fee"].sum()
# Out:
# State
# Andaman                  3144.0
# Andhra pradesh       25305491.0
# Arunachal pradesh     1479417.0
# Assam                 5593554.0
# Bihar                14066979.0
# Chandigarh            3607485.0
# Chhattisgarh          5506292.0
# Delhi ncr            17760023.0
# Goa                   1654922.0
# Gujarat              19383492.0
# Haryana              21287721.0
# Himachal pradesh      8638463.0
# Jammu                 3772653.0
# Jharkhand             6879386.0
# Karnataka            32621983.0
# Kerala               14338006.0
# Madhya pradesh       13893252.0
# Maharashtra          29924091.0
# Manipur                412800.0
# Meghalaya             5756985.0
# Mizoram                443640.0
# Nagaland               814190.0
# Orissa               18078605.0
# Puducherry           12133257.0
# Punjab               21442122.0
# Rajasthan            17946472.0
# Sikkim                2475122.0
# Tamil nadu           14638061.0
# Telangana            25179423.0
# ...

# %% [markdown]
# # Colleges with Palcement Rating Greater than 9

# %%
College.loc[College['Placement'] > 9,['College_Name','Placement']]
# Out:
#                                            College_Name  Placement
# 7                          P.S.G College of Technology         9.1
# 26                                          IIT Bombay         9.1
# 31        National Institute of Industrial Engineering         9.3
# 37                Sardar Patel Institute of Technology         9.1
# 55                      Indian Institute of Technology         9.1
# ...                                                 ...        ...
# 2881  Rungta Group of Institutions Bhilai Campus, Bh...        9.1
# 2886  Rungta College of Pharmaceutical Sciences and ...        9.1
# 3091  Jawaharlal Institute of Post Graduate Medical ...        9.1
# 3105  Jawaharlal Institute of Post Graduate Medical ...        9.1
# 3134             Tripura Medical College, West Tripura         9.3
#
# [80 rows x 2 columns]

# %% [markdown]
# # State and Colleges with Engineering Fees greater than 5 Lakhs

# %%
eng_data=College[(College["Stream"]=="Engineering")&(College["UG_fee"]>500000)]
eng_data
# Out:
#                                           College_Name          State  \
# 31       National Institute of Industrial Engineering     Maharashtra
# 35                  GH Raisoni College of Engineering     Maharashtra
# 77      Noida Institute of Engineering and Technology   Uttar pradesh
# 104     Noida Institute of Engineering and Technology       Delhi ncr
# 158                    Alliance University, Bangalore       Karnataka
# 178     Sreenidhi Institute of Science and Technology       Telangana
# 294   Dr BR Ambedkar National Institute of Technology          Punjab
# 345                   Silicon Institute of Technology          Orissa
# 360        University of Petroleum and Energy Studies     Uttarakhand
# 2479                 National Institute of Technology           Jammu
#
#            Stream     UG_fee    PG_fee  Rating  Academic  Accommodation  \
# 31    Engineering   598000.0  104000.0     9.0       9.0            9.0
# ...

# %% [markdown]
# # Average UG_Fees of Commerce Stream in Maharashtra

# %%
College[(College["Stream"]=="Commerce")&(College["State"]=="Maharashtra")]["UG_fee"].mean()
# Out:
# 21404.375

# %% [markdown]
# # Average UG_Fees of Science Stream in Maharashtra

# %%
College[(College["Stream"]=="Science")&(College["State"]=="Maharashtra")]["UG_fee"].mean()
# Out:
# 47297.625

# %% [markdown]
# # Average UG_Fee of Engineering Colleges in Tamil nadu

# %%
College[(College["Stream"]=="Engineering")&(College["State"]=="Tamil nadu")]["UG_fee"].mean()
# Out:
# 97216.57692307692

# %% [markdown]
# # Top 5 Medical Colleges with Highest UG_fee

# %%
Medicaldata=College[College["Stream"]=="Medical"]
Medicaldata
Medicaldata.sort_values(by="UG_fee",ascending=False).head()
# Out:
#                                            College_Name           State  \
# 1788  Chalmeda Anand Rao Institute of Medical Sciences        Telangana
# 2838                  Katihar Medical College, Katihar            Bihar
# 1759  GSL Medical College and General Hospital, Raja...  Andhra pradesh
# 1791  Kaloji Narayana Rao University of Health Scien...       Telangana
# 1697               D Y Patil Medical College, Kolhapur      Maharashtra
#
#        Stream     UG_fee     PG_fee  Rating  Academic  Accommodation  Faculty  \
# 1788  Medical  5000000.0  7200000.0     6.8       7.8            6.5      7.0
# 2838  Medical  2650000.0  1150000.0     8.6       8.7            8.7      8.7
# 1759  Medical  2420000.0  2420000.0     7.9       8.1            6.8      8.0
# 1791  Medical  2420000.0   225000.0     8.3       8.8            8.0      8.4
# 1697  Medical  2200000.0  3220000.0     6.7       7.0            5.6      7.4
#
#       Infrastructure  Placement  Social_Life
# ...

# %% [markdown]
# # Boxplot for Rating

# %%
sns.boxplot(College["Rating"])
plt.show()

# %% [markdown]
# # Stream vs PG_fee

# %%
sns.set(rc={"figure.figsize":(16,5)})
sns.barplot(x="Stream",y="PG_fee",data=College)
plt.show()

# %%
sns.set(rc={"figure.figsize":(16,5)})
sns.lineplot(x="Stream",y="Accommodation",data=College)
plt.show()

# %% [markdown]
# # Stream vs UG_fee

# %%
sns.set(rc={"figure.figsize":(16,5)})
sns.barplot(x="Stream",y="UG_fee",data=College)
plt.show()

# %% [markdown]
# # Stream vs Placement

# %%
sns.set(rc={"figure.figsize":(16,5)})
sns.barplot(x="Stream",y="Placement",data=College)
plt.show()

# %%
import warnings                # To ignore warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Social_Life

# %%
sns.set(rc={"figure.figsize":(16,5)})
sns.distplot(College["Social_Life"])
plt.show()

# %% [markdown]
# # Top Engineering Colleges with Placement Rating

# %%
sns.set(rc={"figure.figsize":(40,10)})
sns.barplot(x="College_Name",y="Placement",data=eng_data)
plt.show()
